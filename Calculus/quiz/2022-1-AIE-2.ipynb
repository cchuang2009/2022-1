# %% [markdown]
#  <font style="font-size:2em"><div align="center"><b> Calculus, 2022-1-2</b></div></font>
#
#  <font style="font-size:1.6em">Name:  ___________________,</font>            <font style="font-size:1.6em">Sequence Number: </font>

# %% [markdown]
# <big><big>
# <big><b>1$^\circ$).</b></big>
# Evaluate the following Integrations: (total 100%, each 10% ($\color{brown}{\times10}$))<br />
# a$^\circ$). $\mathbf{\int^{2}_0(2x^3-3x^2-2)dx}$                 <br>
# b$^\circ$). $\mathbf{\int^{\pi/4}_{0}\sin x\cos^2 x}dx$<br>
# c$^\circ$). $\mathbf{\int^{\pi/2}_0\sin^4 x dx}$ <br />
# d$^\circ$). $\mathbf{\int^1_{-1}{x^2 e^{-x}}dx}$ <br>
# e$^\circ$). $\mathbf{\int^{\pi/2}_0e^{-x}\sin 3x dx}$ <br>
# f$^\circ$). $\mathbf{\int_1^{2} \frac{\sqrt{4-x^2}}{x} dx }$<br />
# g$^\circ$). $\mathbf{\int_0^{1}\frac{1}{(1+x^2)^2}dx}$<br>
# h$^\circ$). $\mathbf{\int^{4}_{2}\frac{1}{x^3-3x^2}dx } $<br>
# i$^\circ$). $\mathbf{\int_{0}^{\pi/3}\sin2x\sin3x dx}$<br>
# j$^\circ$). $\mathbf{\int_1^2x^2\ln xdx} $<br>
# </big> </big>

# %% [markdown]
# <big><big>
# <big><b>2$^\circ$).</b></big> (total 10%) Describe what the Fundamental Theorem of Calculus is. Suppose that $f(x)=x\sqrt{2-x}$ on interval $I=[0,2]$.  What is the mean value of $f(x)$ on $I$? And  evaluate the derivative
# $$\mathbf{\frac{d}{dx}\int^{x}_{x^2} f(t)dt}$$
# </big> </big>

# %% [markdown]
# <big><big>
# <big><b>3$^\circ$).</b></big> (total 30%, each 10%) Suppose that $f(x)=x^2$, $x \in (1,
#   2)$. And let $S$ be the region enclosed by $y=f(x)$, $X$-axis, $x=1$ and $x=2$.<br>
# a$^\circ$). Find the arc length of curve of $f(x)$ from $(1,1)$ to $(2,4)$.<br>
# b$^\circ$). Find the volume of solid generated by revolving $S$ about $Y$-axis. <br>
# c$^\circ$). Find the surface area of solid generated by revolving arc of $f (x) = x^2$, $x \in (1,2)$, about $X$-axis <br>
# </big> </big>

# %% [markdown]
# Answer
# ---

# %%
Int
# Out:
# -sqrt(3) + 2*acosh(2)

# %%
integrate(sin(x)**4,[x,0,pi/3])
# Out:
# -9*sqrt(3)/64 + pi/8

# %%
cos(pi/3)**3 -cos(pi/3)+2/3
# Out:
# 0.291666666666667

# %%
5/24
# Out:
# 0.20833333333333334

# %%
from sympy import *

# %%
x,t,u,C =symbols("x t u C")

# %%
from sympy import exp,sin,cos,tan,pi,sqrt
from mpmath import e

# %%
def Int(f,*args):
    if(len(args)!=0):
       a=args[0]
       b=args[1]
       print("                          ",b)
       print("The definite integral of  ʃ %s dx is " %f)
       print("                          ",a)
       pprint(integrate(f,(x,a,b)))
    else:
       print("The indefinite integral of  ʃ %s dx is " %f) 
       pprint(integrate(f,x)+C)

# %%
#1.a)
Int(2*x**3-3*x**2-2,0, 2)
# Out:
#                            2
# The definite integral of  ʃ 2*x**3 - 3*x**2 - 2 dx is
#                            0
# -4

# %%
#1.b)
Int((cos(x))**2*sin(x),0,pi/4)
# Out:
#                            pi/4
# The definite integral of  ʃ sin(x)*cos(x)**2 dx is
#                            0
# 1   √2
# ─ - ──
# 3   12

# %%
# 1. c)
Int(sin(x)**4,0,pi/2)
# Out:
#                            pi/2
# The definite integral of  ʃ sin(x)**4 dx is
#                            0
# 3⋅π
# ───
#  16

# %%
#1.d)
Int(x**2*exp(-x),-1,1)
# Out:
#                            1
# The definite integral of  ʃ x**2*exp(-x) dx is
#                            -1
#        -1
# ℯ - 5⋅ℯ

# %%
#1. e)
Int(exp(-x)*sin(3*x),0,pi/2)
# Out:
#                            pi/2
# The definite integral of  ʃ exp(-x)*sin(3*x) dx is
#                            0
#  -π
#  ───
#   2
# ℯ      3
# ──── + ──
#  10    10

# %%
#1. f)
Int(sqrt(4-x*x)/x,1,2)
# Out:
#                            2
# The definite integral of  ʃ sqrt(4 - x**2)/x dx is
#                            1
# -√3 + 2⋅acosh(2)

# %%
f=sqrt(4-x**2)/x
scale_func(f,x,2*u)
# Out:
# Let $x = 2 u$:\begin{eqnarray}\int \frac{\sqrt{4 - x^{2}}}{x} dx &=& \int \frac{2 \sqrt{1 - u^{2}}}{u} du\end{eqnarray}

# %%
f1=2*sqrt(1-u**2)/u
Integration_TrigonometricSubstitution(f1,u,sin(t))
# Out:
# Replacing $u=\sin{\left(θ \right)}$ gets:\begin{eqnarray}\int \frac{2 \sqrt{1 - u^{2}}}{u} d u&=& \int \frac{2 \cos{\left(θ \right)}}{\tan{\left(θ \right)}} d 𝜽 \cr&=& \log{\left(\cos{\left(θ \right)} - 1 \right)} - \log{\left(\cos{\left(θ \right)} + 1 \right)} + 2 \cos{\left(θ \right)} +C \cr\end{eqnarray}

# %%
u1=1/2
u2=1
def F(u):
    return log(sqrt(1-u**2)-1)-log(sqrt(1-u**2)+1)+2*sqrt(1-u**2)

# %%
F(u)
# Out:
# 2*sqrt(1 - u**2) + log(sqrt(1 - u**2) - 1) - log(sqrt(1 - u**2) + 1)

# %%
F(u2)-F(u1)
# Out:
# 0.901864986280756

# %%
#1. g)
Int(1/(1+x**2)**2,0,1)
# Out:
#                            1
# The definite integral of  ʃ (x**2 + 1)**(-2) dx is
#                            0
# 1   π
# ─ + ─
# 4   8

# %%
#1. h)
Int(1/(x**3-3*x**2),2,4)
# Out:
#                            4
# The definite integral of  ʃ 1/(x**3 - 3*x**2) dx is
#                            2
# nan

# %%
#1. i
Int(sin(2*x)*sin(3*x),0,pi/3)
# Out:
#                            pi/3
# The definite integral of  ʃ sin(2*x)*sin(3*x) dx is
#                            0
# 3⋅√3
# ────
#  10

# %%
#1. j
Int(x**2*log(x),1,2)
# Out:
#                            2
# The definite integral of  ʃ x**2*log(x) dx is
#                            1
#   7   8⋅log(2)
# - ─ + ────────
#   9      3

# %%
#2.

# %% [markdown]
# $$\frac{d}{dx}\int_{x^2}^x t\sqrt{2-t}dt=x\sqrt{2-x}-2x^3\sqrt{2-x^2}$$

# %%
Int(x*sqrt(2-x),0,2)
# Out:
#                            2
# The definite integral of  ʃ x*sqrt(2 - x) dx is
#                            0
# 16⋅√2
# ─────
#   15

# %% [markdown]
# Mean = $\frac{8\sqrt2}{15}$

# %%
#3, a

f=x*x
arc=Int(sqrt(1+diff(f,x)**2),1,2)
# Out:
#                            2
# The definite integral of  ʃ sqrt(4*x**2 + 1) dx is
#                            1
#   √5   asinh(2)   asinh(4)
# - ── - ──────── + ──────── + √17
#   2       4          4

# %%
from MultipleCalculus import *

# %%
f1=sqrt(1+4*x**2)
scale_func(f1,x,u/2)
# Out:
# Let $x = \frac{u}{2}$:\begin{eqnarray}\int \sqrt{4 x^{2} + 1} dx &=& \int \frac{\sqrt{u^{2} + 1}}{2} du\end{eqnarray}

# %%
Integration_TrigonometricSubstitution(sqrt(1+u**2),u,tan(t))
# Out:
# Replacing $u=\tan{\left(θ \right)}$ gets:\begin{eqnarray}\int \sqrt{u^{2} + 1} d u&=& \int \sec^{3}{\left(θ \right)} d 𝜽 \cr&=& - \frac{\log{\left(\sin{\left(θ \right)} - 1 \right)}}{4} + \frac{\log{\left(\sin{\left(θ \right)} + 1 \right)}}{4} - \frac{\sin{\left(θ \right)}}{2 \sin^{2}{\left(θ \right)} - 2} +C \cr\end{eqnarray}

# %%
u1=2/sqrt(5)
u2=4/sqrt(17)
def F(u):
    return (log((u+1)/(u-1))/8-u/(4*u**2-4))

# %%
simplify(F(u2)-F(u1))
# Out:
# -sqrt(5)/2 - log(4*sqrt(5) + 9)/8 + log(8*sqrt(17) + 33)/8 + sqrt(17)

# %% [markdown]
# 1. $x\in[1,2]\to u=2x\in[2,4]$.
# 2. $u=\tan(\theta)\to \sin(\theta)=\frac{u}{\sqrt{1+u^2}}$
# 3. arc is
# $$ \left.{\left(\ln\left(\frac{4/\sqrt{17}+1}{4/\sqrt{17}-1}\right)-\frac{4/\sqrt{17}}{32/17-2}-\ln\left(\frac{2/\sqrt{5}+1}{2/\sqrt{5}-1}\right)+\frac{2/\sqrt{5}}{8/5-2}\right)}\right/2$$

# %%
f=x*x
f1=sqrt(1+diff(f,x)**2)
Integration_TrigonometricSubstitution_v5(f1,x,tan(t),s=1/2,interval=[1,2])
# Out:
# Replacing $x=0.5\cdot \tan{\left(θ \right)}, \left( \text{ i.e. } \color{brown}{θ=\operatorname{atan}{\left(2.0 x \right)}}\right)$, gets:\begin{eqnarray}\int \sqrt{4 x^{2} + 1} d x&=& \int 0.5 \sec^{3}{\left(θ \right)} d 𝜽 \cr&=& - 0.125 \log{\left(\left|{\sin{\left(θ \right)} - 1}\right| \right)} + 0.125 \log{\left(\left|{\sin{\left(θ \right)} + 1}\right| \right)} - \frac{0.5 \sin{\left(θ \right)}}{2 \sin^{2}{\left(θ \right)} - 2} +C \cr&=& \frac{0.5 x \left(2.0 x^{2} + 0.5\right) + 0.125 \sqrt{x^{2} + 0.25} \left(- \log{\left(\frac{\left|{1.0 x - \sqrt{x^{2} + 0.25}}\right|}{\left|{\sqrt{x^{2} + 0.25}}\right|} \right)} + \log{\left(\frac{\left|{1.0 x + \sqrt{x^{2} + 0.25}}\right|}{\left|{\sqrt{x^{2} + 0.25}}\right|} \right)}\right)}{\sqrt{x^{2} + 0.25}} +C \cr\end{eqnarray}Then \begin{eqnarray}&&\int_{1}^{2} \sqrt{4 x^{2} + 1} d x \cr  &=& \left. \frac{0.5 x \left(2.0 x^{2} + 0.5\right) + 0.125 \sqrt{x^{2} + 0.25} \left(- \log{\left(\frac{\left|{1.0 x - \sqrt{x^{2} + 0.25}}\right|
# ...

# %%
f=x*x
f1=sqrt(1+diff(f,x)**2)
Integration_TrigonometricSubstitution_v5(f1,x,tan(t),s=1/2,interval=[1,3])
# Out:
# Replacing $x=0.5\cdot \tan{\left(θ \right)}, \left( \text{ i.e. } \color{brown}{θ=\operatorname{atan}{\left(2.0 x \right)}}\right)$, gets:\begin{eqnarray}\int \sqrt{4 x^{2} + 1} d x&=& \int 0.5 \sec^{3}{\left(θ \right)} d 𝜽 \cr&=& - 0.125 \log{\left(\left|{\sin{\left(θ \right)} - 1}\right| \right)} + 0.125 \log{\left(\left|{\sin{\left(θ \right)} + 1}\right| \right)} - \frac{0.5 \sin{\left(θ \right)}}{2 \sin^{2}{\left(θ \right)} - 2} +C \cr&=& \frac{0.5 x \left(2.0 x^{2} + 0.5\right) + 0.125 \sqrt{x^{2} + 0.25} \left(- \log{\left(\frac{\left|{1.0 x - \sqrt{x^{2} + 0.25}}\right|}{\left|{\sqrt{x^{2} + 0.25}}\right|} \right)} + \log{\left(\frac{\left|{1.0 x + \sqrt{x^{2} + 0.25}}\right|}{\left|{\sqrt{x^{2} + 0.25}}\right|} \right)}\right)}{\sqrt{x^{2} + 0.25}} +C \cr\end{eqnarray}Then \begin{eqnarray}&&\int_{1}^{3} \sqrt{4 x^{2} + 1} d x \cr  &=& \left. \frac{0.5 x \left(2.0 x^{2} + 0.5\right) + 0.125 \sqrt{x^{2} + 0.25} \left(- \log{\left(\frac{\left|{1.0 x - \sqrt{x^{2} + 0.25}}\right|
# ...

# %%
f=x*x
f1=2*pi*x*f
Integration_TrigonometricSubstitution_v5(f1,x,tan(t),s=1/2,interval=[1,3])

# %%
#3 b)
f2=2*pi*x*f
Int(f2,1,2)
# Out:
#                            2
# The definite integral of  ʃ 2*pi*x**3 dx is
#                            1
# 15⋅π
# ────
#  2

# %%
#3 b)
f=x**2
f2=2*pi*x*f
Int(f2,1,3)
# Out:
#                            3
# The definite integral of  ʃ 2*pi*x**3 dx is
#                            1
# 40⋅π

# %%
#3 c)
f3=2*pi*f*sqrt(1+diff(f,x)**2)
f3
# Out:
# 2*pi*x**2*sqrt(4*x**2 + 1)

# %%
scale_func(f3,x,u/2)
# Out:
# Let $x = \frac{u}{2}$:\begin{eqnarray}\int 2 \pi x^{2} \sqrt{4 x^{2} + 1} dx &=& \int \frac{\pi u^{2} \sqrt{u^{2} + 1}}{4} du\end{eqnarray}

# %%
f4=pi*u**2*sqrt(1+u**2)/4
Integration_TrigonometricSubstitution(f4,u,tan(t))
# Out:
# Replacing $u=\tan{\left(θ \right)}$ gets:\begin{eqnarray}\int \frac{\pi u^{2} \sqrt{u^{2} + 1}}{4} d u&=& \int \frac{\pi \tan^{2}{\left(θ \right)} \sec^{3}{\left(θ \right)}}{4} d 𝜽 \cr&=& \frac{\pi \left(\frac{\sin^{3}{\left(θ \right)} + \sin{\left(θ \right)}}{8 \sin^{4}{\left(θ \right)} - 16 \sin^{2}{\left(θ \right)} + 8} + \frac{\log{\left(\sin{\left(θ \right)} - 1 \right)}}{16} - \frac{\log{\left(\sin{\left(θ \right)} + 1 \right)}}{16}\right)}{4} +C \cr\end{eqnarray}

# %%
u1=2/sqrt(5)
u2=4/sqrt(17)
def F(u):
    return pi*((u**2+u)/(8*u**4-16*u**2+8)+log(u-1)/16-log(u+1)/16)/4

# %%
simplify(F(u2)-F(u1))
# Out:
# pi*(-20*sqrt(5) + log((1 - 4*sqrt(17)/17)*(2*sqrt(5)/5 + 1)/((1 - 2*sqrt(5)/5)*(4*sqrt(17)/17 + 1))) + 504 + 136*sqrt(17))/64

# %%
N(simplify(F(u2)-F(u1)))
# Out:
# 50.0062446812462

# %%
Integration_TrigonometricSubstitution_v3(f3,x,tan(t)/2,s=1/2,interval=[1,2])
# Out:
# Replacing $x=\frac{\tan{\left(θ \right)}}{2}, \left( \text{ i.e. } θ=\operatorname{atan}{\left(2.0 x \right)}\right)$, gets:\begin{eqnarray}\int 2 \pi x^{2} \sqrt{4 x^{2} + 1} d x&=& \int \frac{\pi \tan^{2}{\left(θ \right)} \sec^{3}{\left(θ \right)}}{4} d 𝜽 \cr&=& \frac{\pi \left(\frac{\sin^{3}{\left(θ \right)} + \sin{\left(θ \right)}}{8 \sin^{4}{\left(θ \right)} - 16 \sin^{2}{\left(θ \right)} + 8} + \frac{\log{\left(\sin{\left(θ \right)} - 1 \right)}}{16} - \frac{\log{\left(\sin{\left(θ \right)} + 1 \right)}}{16}\right)}{4} +C \cr&=& \pi \left(1.0 x^{3} \sqrt{x^{2} + 0.25} + 0.125 x \sqrt{x^{2} + 0.25} + 0.015625 \log{\left(\frac{1.0 x}{\sqrt{x^{2} + 0.25}} - 1 \right)} - 0.015625 \log{\left(\frac{1.0 x}{\sqrt{x^{2} + 0.25}} + 1 \right)}\right) +C \cr\end{eqnarray}Then \begin{eqnarray}\int_{1}^{2} 2 \pi x^{2} \sqrt{4 x^{2} + 1} d x = \left. \pi \left(1.0 x^{3} \sqrt{x^{2} + 0.25} + 0.125 x \sqrt{x^{2} + 0.25} + 0.015625 \log{\left(\frac{1.0 x}{\sqrt{x^{2} + 0.25}} - 1 \right)} - 0.0
# ...

# %%
integrate(2*pi*x**3,[x,1,3])
# Out:
# 40*pi

# %%
f=x**2
f3=2*pi*f*sqrt(1+diff(f,x)**2)
Integration_TrigonometricSubstitution_v5(f3,x,tan(t),s=1/2,interval=[1,3])
# Out:
# Replacing $x=0.5\cdot \tan{\left(θ \right)}, \left( \text{ i.e. } \color{brown}{θ=\operatorname{atan}{\left(2.0 x \right)}}\right)$, gets:\begin{eqnarray}\int 2 \pi x^{2} \sqrt{4 x^{2} + 1} d x&=& \int 0.25 \pi \sin^{2}{\left(θ \right)} \sec^{5}{\left(θ \right)} d 𝜽 \cr&=& 0.25 \pi \left(\frac{\sin^{3}{\left(θ \right)} + \sin{\left(θ \right)}}{8 \sin^{4}{\left(θ \right)} - 16 \sin^{2}{\left(θ \right)} + 8} + \frac{\log{\left(\left|{\sin{\left(θ \right)} - 1}\right| \right)}}{16} - \frac{\log{\left(\left|{\sin{\left(θ \right)} + 1}\right| \right)}}{16}\right) +C \cr&=& \pi \left(1.0 x^{3} \sqrt{x^{2} + 0.25} + 0.125 x \sqrt{x^{2} + 0.25} + 0.015625 \log{\left(\frac{\left|{1.0 x - \sqrt{x^{2} + 0.25}}\right|}{\left|{\sqrt{x^{2} + 0.25}}\right|} \right)} - 0.015625 \log{\left(\frac{\left|{1.0 x + \sqrt{x^{2} + 0.25}}\right|}{\left|{\sqrt{x^{2} + 0.25}}\right|} \right)}\right) +C \cr\end{eqnarray}Then \begin{eqnarray}&&\int_{1}^{3} 2 \pi x^{2} \sqrt{4 x^{2} + 1} d x \cr  &=& \left. \pi \
# ...

# %%
81.967*3.14
# Out:
# 257.37638

# %%
f=1/(4+x**2)**2
Integration_TrigonometricSubstitution_v5(f,x,tan(t),s=2,interval=[0,2])
# Out:
# Replacing $x=2\cdot \tan{\left(θ \right)}, \left( \text{ i.e. } \color{brown}{θ=\operatorname{atan}{\left(\frac{x}{2} \right)}}\right)$, gets:\begin{eqnarray}\int \frac{1}{\left(x^{2} + 4\right)^{2}} d x&=& \int \frac{\cos^{2}{\left(θ \right)}}{8} d 𝜽 \cr&=& \frac{θ}{16} + \frac{\sin{\left(θ \right)} \cos{\left(θ \right)}}{16} +C \cr&=& \frac{2 x + \left(x^{2} + 4\right) \operatorname{atan}{\left(\frac{x}{2} \right)}}{16 x^{2} + 64} +C \cr\end{eqnarray}Then \begin{eqnarray}&&\int_{0}^{3} \frac{1}{\left(x^{2} + 4\right)^{2}} d x \cr  &=& \left. \frac{2 x + \left(x^{2} + 4\right) \operatorname{atan}{\left(\frac{x}{2} \right)}}{16 x^{2} + 64} \right]_{0}^{3} \cr  &=& 0.0902707615491119 - (0)\cr &=& 0.0902707615491119 \end{eqnarray}

# %%
f=1/(9+x**2)**2
Integration_TrigonometricSubstitution_v5(f,x,tan(t),s=3,interval=[0,3])
# Out:
# Replacing $x=3\cdot \tan{\left(θ \right)}, \left( \text{ i.e. } \color{brown}{θ=\operatorname{atan}{\left(\frac{x}{3} \right)}}\right)$, gets:\begin{eqnarray}\int \frac{1}{\left(x^{2} + 9\right)^{2}} d x&=& \int \frac{\cos^{2}{\left(θ \right)}}{27} d 𝜽 \cr&=& \frac{θ}{54} + \frac{\sin{\left(θ \right)} \cos{\left(θ \right)}}{54} +C \cr&=& \frac{3 x + \left(x^{2} + 9\right) \operatorname{atan}{\left(\frac{x}{3} \right)}}{54 x^{2} + 486} +C \cr\end{eqnarray}Then \begin{eqnarray}&&\int_{0}^{3} \frac{1}{\left(x^{2} + 9\right)^{2}} d x \cr  &=& \left. \frac{3 x + \left(x^{2} + 9\right) \operatorname{atan}{\left(\frac{x}{3} \right)}}{54 x^{2} + 486} \right]_{0}^{3} \cr  &=& 0.00925925925925926 + \frac{\pi}{216} - (0)\cr &=& 0.00925925925925926 + \frac{\pi}{216} \end{eqnarray}

# %%
f=1/(r**2+x**2)**2
Integration_TrigonometricSubstitution_v5(f,x,tan(t),s=r,interval=[0,r])
# Out:
# Replacing $x=r\cdot \tan{\left(θ \right)}, \left( \text{ i.e. } \color{brown}{θ=\operatorname{atan}{\left(\frac{x}{r} \right)}}\right)$, gets:\begin{eqnarray}\int \frac{1}{\left(r^{2} + x^{2}\right)^{2}} d x&=& \int \frac{\cos^{2}{\left(θ \right)}}{r^{3}} d 𝜽 \cr&=& \frac{\frac{θ}{2} + \frac{\sin{\left(θ \right)} \cos{\left(θ \right)}}{2}}{r^{3}} +C \cr&=& \frac{r x + \left(r^{2} + x^{2}\right) \operatorname{atan}{\left(\frac{x}{r} \right)}}{2 r^{3} \left(r^{2} + x^{2}\right)} +C \cr\end{eqnarray}Then \begin{eqnarray}&&\int_{0}^{r} \frac{1}{\left(r^{2} + x^{2}\right)^{2}} d x \cr  &=& \left. \frac{r x + \left(r^{2} + x^{2}\right) \operatorname{atan}{\left(\frac{x}{r} \right)}}{2 r^{3} \left(r^{2} + x^{2}\right)} \right]_{0}^{r} \cr  &=& \frac{r^{2} + \frac{\pi r^{2}}{2}}{4 r^{5}} - (0)\cr &=& \frac{r^{2} + \frac{\pi r^{2}}{2}}{4 r^{5}} \end{eqnarray}

# %%
Int(1/(x**3-6*x**2))#,2,4)
# Out:
# The indefinite integral of  ʃ 1/(x**3 - 6*x**2) dx is
#     log(x)   log(x - 6)    1
# C - ────── + ────────── + ───
#       36         36       6⋅x

# %%
a=3
f=x*sqrt(a-x)
Int(f,0,a)
# Out:
#                            3
# The definite integral of  ʃ x*sqrt(3 - x) dx is
#                            0
# 12⋅√3
# ─────
#   5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 3
#       1 a=3
#       2 f=x*sqrt(a-x)
# ----> 3 Int(f,0,a)/a
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
f=x*sqrt(1-x)
integrate(f,[x,0,1])
# Out:
# 4/15

# %%
from sympy import Symbol,N
s=Symbol("s")
fs=s*integrate(t*sqrt(1-t),[t,s,1])

# %%
fs
# Out:
# s*Piecewise((2*s**2*sqrt(1 - s)/5 - 2*s*sqrt(1 - s)/15 - 4*sqrt(1 - s)/15 - 2*sqrt(1 - Min(1, Max(-1, s)))*Min(1, Max(-1, s))**2/5 + 2*sqrt(1 - Min(1, Max(-1, s)))*Min(1, Max(-1, s))/15 + 4*sqrt(1 - Min(1, Max(-1, s)))/15 + 2*I*sqrt(Min(1, Max(-1, s)) - 1)*Min(1, Max(-1, s))**2/5 - 2*I*sqrt(Min(1, Max(-1, s)) - 1)*Min(1, Max(-1, s))/15 - 4*I*sqrt(Min(1, Max(-1, s)) - 1)/15, s < 1), (-2*I*s**2*sqrt(s - 1)/5 + 2*I*s*sqrt(s - 1)/15 + 4*I*sqrt(s - 1)/15, True))

# %%
N(integrate(sin(5*x)*cos(6*x),[x,0,pi/2]))
# Out:
# -0.454545454545455
