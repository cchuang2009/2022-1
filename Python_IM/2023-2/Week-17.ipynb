# %% [markdown]
# ```
#   少年不知愁滋味，為賦新詞強說愁
#   馬齒漸長力不滯，程式編碼空徒勞
#                -- 切特•基匹梯
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [raw]
# !pip install pyecharts

# %%
# load webpage resource
url='../../../Desktop/cgu_lecture.html'
pages=pd.read_html(url)

# %%
# Find out where the table we want
cgu=pages[12]

# %%
# copy whole the table except the columns of features
df=cgu[1:]

# %%
# reset columns of DataFrame 
df.columns=cgu.loc[0,:].values

# %%
import mitosheet

# %%
df.reset_index(inplace=True)
df
# Out:
#      index 學年/學期 Semester 科目代號 Course Code 開課序號 Serial No. 開課單位 Department  \
# 0        1         112/ 1           GA0001           58980            通識中心
# 1        2         112/ 1           GA0002           58981            通識中心
# 2        3         112/ 1           GA0003           58982            通識中心
# 3        4         112/ 1           GA0004           58983            通識中心
# 4        5         112/ 1           GA0006           58984            通識中心
# ..     ...            ...              ...             ...             ...
# 153    154         112/ 1           GT0137           59877            通識中心
# 154    155         112/ 1           GT0137           59878            通識中心
# 155    156         112/ 1           GT0172           59976            通識中心
# 156    157         112/ 1           GT0172           59977            通識中心
# 157    158         112/ 1           GT0172           59978            通識中心
#
#     年級 Year                                  課程名稱 Course Title  \
# 0         1  從急救案例到人生省思 Reflection of Life from First Aid c...
# 1         1  創新、創意、創業開發課程 Innovation, creativity, and entre...
# 2         1  龜山區稻米產業多元化-清酒釀造 Diversify rice industry in Gui...
# 3         1  龜山區稻米產業多元化-清酒釀造(場域) Diversify rice industry in...
# 4         1  服務學習與營隊活動導論2-活動規劃 Introduction to Service-Lear...
# ..      ...                                                ...
# 153       2            資料處理與應用 Introduction of Data Processing
# 154       2            資料處理與應用 Introduction of Data Processing
# 155       1                          程式語言 Programming Language
# 156       1                          程式語言 Programming Language
# 157       1                          程式語言 Programming Language
#
#     授課教師 Instructor 學分 Credits 上課時間 Class Sched. 選課人數 Seats
# 0               牟永平          2   Thu 10:10-12:00      60/60
# 1               王永樑          2   Thu 10:10-12:00      52/60
# 2               何金龍          1     0 00:00-00:00      20/20
# 3               何金龍       0.50     0 00:00-00:00      20/20
# 4               何金龍       0.40     0 00:00-00:00      31/60
# ..              ...        ...               ...        ...
# 153             李榮宗          2   Fri 10:10-12:00      40/40
# 154             陳偉忠          2   Wed 13:10-15:00      23/40
# 155            待聘教師          2   Tue 10:10-12:00        0/0
# 156            待聘教師          2   Fri 15:10-17:00        0/0
# 157            待聘教師          2   Mon 10:10-12:00        0/0
#
# [158 rows x 11 columns]

# %%
# retrieve the number of person registered for each lecture
df['num']=0
for i in range(0,len(df)):
    # retireve the number before "/"
    df['num'][i]=df['選課人數 Seats'].iloc(0)[i].split('/')[0]
df[:4]
# Out:
# /var/folders/xb/s7vwrt4153xbxzr8hc8tbdtr0000gn/T/ipykernel_61873/1861384055.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num']=0
# /var/folders/xb/s7vwrt4153xbxzr8hc8tbdtr0000gn/T/ipykernel_61873/1861384055.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num'][i]=df['選課人數 Seats'].iloc(0)[i].split('/')[0]
#    index 學年/學期 Semester 科目代號 Course Code 開課序號 Serial No. 開課單位 Department  \
# 0      1         112/ 1           GA0001           58980            通識中心
# 1      2         112/ 1           GA0002           58981            通識中心
# 2      3         112/ 1           GA0003           58982            通識中心
# 3      4         112/ 1           GA0004           58983            通識中心
#
#   年級 Year                                  課程名稱 Course Title 授課教師 Instructor  \
# 0       1  從急救案例到人生省思 Reflection of Life from First Aid c...             牟永平
# 1       1  創新、創意、創業開發課程 Innovation, creativity, and entre...             王永樑
# 2       1  龜山區稻米產業多元化-清酒釀造 Diversify rice industry in Gui...             何金龍
# 3       1  龜山區稻米產業多元化-清酒釀造(場域) Diversify rice industry in...             何金龍
#
#   學分 Credits 上課時間 Class Sched. 選課人數 Seats num
# 0          2   Thu 10:10-12:00      60/60  60
# 1          2   Thu 10:10-12:00      52/60  52
# 2          1     0 00:00-00:00      20/20  20
# 3       0.50     0 00:00-00:00      20/20  20

# %%
df['num']=df['num'].astype(int)
# Out:
# /var/folders/xb/s7vwrt4153xbxzr8hc8tbdtr0000gn/T/ipykernel_61873/2659943025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num']=df['num'].astype(int)

# %%
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
# First view for distributed of registers 
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.histplot(df['num']);

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
# make a categorical feature for size od persions in registered lecture
def classify(x):
    if x<10:
       return '[0,10)'
    elif x<30:
       return '[10,30)' 
    elif x<60:
       return '[30,60)'
    else:
       return '[60,]'

# %%
df
# Out:
#      index 學年/學期 Semester 科目代號 Course Code 開課序號 Serial No. 開課單位 Department  \
# 0        1         112/ 1           GA0001           58980            通識中心
# 1        2         112/ 1           GA0002           58981            通識中心
# 2        3         112/ 1           GA0003           58982            通識中心
# 3        4         112/ 1           GA0004           58983            通識中心
# 4        5         112/ 1           GA0006           58984            通識中心
# ..     ...            ...              ...             ...             ...
# 153    154         112/ 1           GT0137           59877            通識中心
# 154    155         112/ 1           GT0137           59878            通識中心
# 155    156         112/ 1           GT0172           59976            通識中心
# 156    157         112/ 1           GT0172           59977            通識中心
# 157    158         112/ 1           GT0172           59978            通識中心
#
#     年級 Year                                  課程名稱 Course Title  \
# 0         1  從急救案例到人生省思 Reflection of Life from First Aid c...
# 1         1  創新、創意、創業開發課程 Innovation, creativity, and entre...
# 2         1  龜山區稻米產業多元化-清酒釀造 Diversify rice industry in Gui...
# 3         1  龜山區稻米產業多元化-清酒釀造(場域) Diversify rice industry in...
# 4         1  服務學習與營隊活動導論2-活動規劃 Introduction to Service-Lear...
# ..      ...                                                ...
# 153       2            資料處理與應用 Introduction of Data Processing
# 154       2            資料處理與應用 Introduction of Data Processing
# 155       1                          程式語言 Programming Language
# 156       1                          程式語言 Programming Language
# 157       1                          程式語言 Programming Language
#
#     授課教師 Instructor 學分 Credits 上課時間 Class Sched. 選課人數 Seats  num
# 0               牟永平          2   Thu 10:10-12:00      60/60   60
# 1               王永樑          2   Thu 10:10-12:00      52/60   52
# 2               何金龍          1     0 00:00-00:00      20/20   20
# 3               何金龍       0.50     0 00:00-00:00      20/20   20
# 4               何金龍       0.40     0 00:00-00:00      31/60   31
# ..              ...        ...               ...        ...  ...
# 153             李榮宗          2   Fri 10:10-12:00      40/40   40
# 154             陳偉忠          2   Wed 13:10-15:00      23/40   23
# 155            待聘教師          2   Tue 10:10-12:00        0/0    0
# 156            待聘教師          2   Fri 15:10-17:00        0/0    0
# 157            待聘教師          2   Mon 10:10-12:00        0/0    0
#
# [158 rows x 12 columns]

# %%
df['Class']=df['num'].apply(classify)
# Out:
# /var/folders/xb/s7vwrt4153xbxzr8hc8tbdtr0000gn/T/ipykernel_61873/3538006182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class']=df['num'].apply(classify)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.histplot(df['Class'],discrete=True, shrink=0.8,);

# %%
Class_count
# Out:
# Class
# [10,30)    53
# [30,60)    49
# [0,10)     29
# [60,]      27
# Name: count, dtype: int64

# %%
bins=['[0,10)','[10,30)','[30,60)','[60,]']
Class_count=df[['Class']].value_counts()
count_bins=[Class_count[bin] for bin in bins]

# %%
count_bins==[29, 53, 49, 27]
# Out:
# True

# %% [markdown]
# Class_dic=df[['Class']].value_counts().to_dict()

# %%
len(bins),len(count_bins)
# Out:
# (4, 4)

# %%
# 不习惯链式调用的开发者依旧可以单独调用方法
bar = Bar()
#bar.add_xaxis(list(Class_dic.keys()))
bar.add_xaxis(bins)
#bar.add_yaxis("選課人數", count_bins)
bar.add_yaxis("課程數目",[29, 53, 49, 27])
bar.set_global_opts(title_opts=opts.TitleOpts(
    title="通識中心 112-1 課程", subtitle='選課人數範圍'),
    #yaxis_opts=opts.AxisOpts(name="課程數"),
    xaxis_opts=opts.AxisOpts(name="選課人數"),                
    )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3e86c8d2f724404d912eb3dc2a49ce90" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3e86c8d2f724404d912eb3dc2a49ce90 = echarts.init(
#                     document.getElementById('3e86c8d2f724404d912eb3dc2a49ce90'), 'white', {renderer: 'canvas'});
#                 var option_3e86c8d2f724404d912eb3dc2a49ce90 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8ab2\u7a0b\u6578\u76ee",
#             "legendHoverLink": true,
#             "data": [
#                 29,
#                 53,
#                 49,
#                 27
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8ab2\u7a0b\u6578\u76ee"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "\u9078\u8ab2\u4eba\u6578",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "[0,10)",
#                 "[10,30)",
#                 "[30,60)",
#                 "[60,]"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u901a\u8b58\u4e2d\u5fc3 112-1 \u8ab2\u7a0b",
#             "target": "blank",
#             "subtext": "\u9078\u8ab2\u4eba\u6578\u7bc4\u570d",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_3e86c8d2f724404d912eb3dc2a49ce90.setOption(option_3e86c8d2f724404d912eb3dc2a49ce90);
#         });
#     </script>

# %%
 [z for z in zip( bins, count_bins)]==[('[0,10)', 29), ('[10,30)', 53), ('[30,60)', 49), ('[60,]', 27)]
# Out:
# True

# %%
Count_bins=count_bins

# %%
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    #.add("", [list(z) for z in zip([ z[0] for z in list(Class_dic)], list(Class_dic.values()))],
    #.add("",  [z for z in zip( bins, Count_bins)],
    .add("",[['[0,10)', 29], ['[10,30)', 53], ['[30,60)', 49], ['[60,]', 27]],        
         radius=["30%", "75%"],
         center=["35%", "50%"],
         rosetype="radius", 
        )
    .set_global_opts(title_opts=opts.TitleOpts(title="通識中心 112-1 課程", 
                                               subtitle='選課人數範圍',
                                               pos_left='left',
                                               pos_top='0%'))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="人數 {b}: {c} 門"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2ff16c09a9274561af4b960ee8ef64d3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2ff16c09a9274561af4b960ee8ef64d3 = echarts.init(
#                     document.getElementById('2ff16c09a9274561af4b960ee8ef64d3'), 'white', {renderer: 'canvas'});
#                 var option_2ff16c09a9274561af4b960ee8ef64d3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "[0,10)",
#                     "value": 29
#                 },
#                 {
#                     "name": "[10,30)",
#                     "value": 53
#                 },
#                 {
#                     "name": "[30,60)",
#                     "value": 49
#                 },
#                 {
#                     "name": "[60,]",
#                     "value": 27
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "\u4eba\u6578 {b}: {c} \u9580"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "[0,10)",
#                 "[10,30)",
#                 "[30,60)",
#                 "[60,]"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u901a\u8b58\u4e2d\u5fc3 112-1 \u8ab2\u7a0b",
#             "target": "blank",
#             "subtext": "\u9078\u8ab2\u4eba\u6578\u7bc4\u570d",
#             "subtarget": "blank",
#             "left": "left",
#             "top": "0%",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_2ff16c09a9274561af4b960ee8ef64d3.setOption(option_2ff16c09a9274561af4b960ee8ef64d3);
#         });
#     </script>

# %%
# explode weekday-duration, "Thu 10:10-12:00", into "weekday" and "duration", two features
def seperate_day_time(df, feature):
    df[feature+'_day'] = df[feature].apply(lambda x: x.split(' ')[0])
    df[feature+'_time'] = df[feature].apply(lambda x: x.split(' ')[1])
    return df

# %%
df=seperate_day_time(df, "上課時間 Class Sched.")
# Out:
# /var/folders/xb/s7vwrt4153xbxzr8hc8tbdtr0000gn/T/ipykernel_61873/1667547705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[feature+'_day'] = df[feature].apply(lambda x: x.split(' ')[0])
# /var/folders/xb/s7vwrt4153xbxzr8hc8tbdtr0000gn/T/ipykernel_61873/1667547705.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[feature+'_time'] = df[feature].apply(lambda x: x.split(' ')[1])

# %%
# determine time is at morring or afternoon
def map_time(df, feature):
    df['time_slot'] = df[feature].apply(lambda x: 'morning' if x.split('-')[0] < '12:00' else 'afternoon' if x.split('-')[0] > '12:00' else 'none')
    return df

df= map_time(df, "上課時間 Class Sched._time")
# Out:
# /var/folders/xb/s7vwrt4153xbxzr8hc8tbdtr0000gn/T/ipykernel_61873/1892084801.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_slot'] = df[feature].apply(lambda x: 'morning' if x.split('-')[0] < '12:00' else 'afternoon' if x.split('-')[0] > '12:00' else 'none')

# %%
df.loc[df['上課時間 Class Sched._day']=='0','上課時間 Class Sched._day']='None'

# %%
sns.histplot(data=df, x="上課時間 Class Sched._day", hue="time_slot");
# Out:
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   func(*args, **kwargs)
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 35506 (\N{CJK UNIFIED IDEOGRAPH-8AB2}) missing from current font.
#   func(*args, **kwargs)
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 26178 (\N{CJK UNIFIED IDEOGRAPH-6642}) missing from current font.
#   func(*args, **kwargs)
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 38291 (\N{CJK UNIFIED IDEOGRAPH-9593}) missing from current font.
#   func(*args, **kwargs)
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 35506 (\N{CJK UNIFIED IDEOGRAPH-8AB2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26178 (\N{CJK UNIFIED IDEOGRAPH-6642}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38291 (\N{CJK UNIFIED IDEOGRAPH-9593}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
person_bins=['[0,10)','[10,30)','[30,60)','[60,]']
person_count_M=df.loc[df['time_slot']=='morning']['Class'].value_counts()
person_count_A=df.loc[df['time_slot']=='afternoon']['Class'].value_counts()

person_count_bins_A=[person_count_A[bin] for bin in person_bins]
person_count_bins_M=[person_count_M[bin] for bin in person_bins]

# %%
person_count_bins_A,person_count_bins_M
# Out:
# ([17, 37, 34, 19], [12, 16, 15, 8])

# %%
# 不习惯链式调用的开发者依旧可以单独调用方法
bar = Bar()
bar.add_xaxis(person_bins)
bar.add_yaxis(" Morning 課程數目", [12, 16, 15, 8])
bar.add_yaxis(" Afternoon 課程數目",[17, 37, 34, 19])
bar.set_global_opts(title_opts=opts.TitleOpts(title="通識中心 112-1 課程", subtitle="上下午課程 人數分布"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b6bcd19b882d4f27804fd6a218f9741f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b6bcd19b882d4f27804fd6a218f9741f = echarts.init(
#                     document.getElementById('b6bcd19b882d4f27804fd6a218f9741f'), 'white', {renderer: 'canvas'});
#                 var option_b6bcd19b882d4f27804fd6a218f9741f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": " Morning \u8ab2\u7a0b\u6578\u76ee",
#             "legendHoverLink": true,
#             "data": [
#                 12,
#                 16,
#                 15,
#                 8
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": " Afternoon \u8ab2\u7a0b\u6578\u76ee",
#             "legendHoverLink": true,
#             "data": [
#                 17,
#                 37,
#                 34,
#                 19
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 " Morning \u8ab2\u7a0b\u6578\u76ee",
#                 " Afternoon \u8ab2\u7a0b\u6578\u76ee"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "[0,10)",
#                 "[10,30)",
#                 "[30,60)",
#                 "[60,]"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u901a\u8b58\u4e2d\u5fc3 112-1 \u8ab2\u7a0b",
#             "target": "blank",
#             "subtext": "\u4e0a\u4e0b\u5348\u8ab2\u7a0b \u4eba\u6578\u5206\u5e03",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_b6bcd19b882d4f27804fd6a218f9741f.setOption(option_b6bcd19b882d4f27804fd6a218f9741f);
#         });
#     </script>

# %%
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    #.add("", [list(z) for z in zip([ z[0] for z in list(Class_dic)], list(Class_dic.values()))],
    #.add("",  [z for z in zip( bins, Count_bins)],
    .add(" 課程選修人數, 開課總數",[['[0,10)', 29], ['[10,30)', 53], ['[30,60)', 49], ['[60,]', 27]],        
         radius=["50%", "75%"],
         center=["35%", "50%"],
         rosetype="radius", 
        )
    .add(" 上午 課程",[['[0,10)', 12], ['[10,30)', 16], ['[30,60)', 15], ['[60,]', 8]],        
         radius=["25%", "38%"],
         center=["35%", "50%"],
         #rosetype="radius", 
        )
    .add(" 下午 課程",[['[0,10)', 17], ['[10,30)', 36], ['[30,60)', 34], ['[60,]', 19]],        
         radius=["10%", "18%"],
         center=["35%", "50%"],
         #rosetype="radius", 
        )
    .set_global_opts(title_opts=opts.TitleOpts(title="通識中心 112-1 課程", 
                                               subtitle='選課人數範圍',
                                               pos_left='left',
                                               pos_top='0%'))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="人數 {b}: {c} 門"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c1ab395f89094ec685a9fcf39bbf3352" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c1ab395f89094ec685a9fcf39bbf3352 = echarts.init(
#                     document.getElementById('c1ab395f89094ec685a9fcf39bbf3352'), 'white', {renderer: 'canvas'});
#                 var option_c1ab395f89094ec685a9fcf39bbf3352 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": " \u8ab2\u7a0b\u9078\u4fee\u4eba\u6578, \u958b\u8ab2\u7e3d\u6578",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "[0,10)",
#                     "value": 29
#                 },
#                 {
#                     "name": "[10,30)",
#                     "value": 53
#                 },
#                 {
#                     "name": "[30,60)",
#                     "value": 49
#                 },
#                 {
#                     "name": "[60,]",
#                     "value": 27
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "75%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "\u4eba\u6578 {b}: {c} \u9580"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "name": " \u4e0a\u5348 \u8ab2\u7a0b",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "[0,10)",
#                     "value": 12
#                 },
#                 {
#                     "name": "[10,30)",
#                     "value": 16
#                 },
#                 {
#                     "name": "[30,60)",
#                     "value": 15
#                 },
#                 {
#                     "name": "[60,]",
#                     "value": 8
#                 }
#             ],
#             "radius": [
#                 "25%",
#                 "38%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "\u4eba\u6578 {b}: {c} \u9580"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "name": " \u4e0b\u5348 \u8ab2\u7a0b",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "[0,10)",
#                     "value": 17
#                 },
#                 {
#                     "name": "[10,30)",
#                     "value": 36
#                 },
#                 {
#                     "name": "[30,60)",
#                     "value": 34
#                 },
#                 {
#                     "name": "[60,]",
#                     "value": 19
#                 }
#             ],
#             "radius": [
#                 "10%",
#                 "18%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "\u4eba\u6578 {b}: {c} \u9580"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "[0,10)",
#                 "[10,30)",
#                 "[30,60)",
#                 "[60,]"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,

# %%
df1=df[df['上課時間 Class Sched._day']!='None']
weekday_bins=['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
weekday_count_M=df1.loc[df1['time_slot']=='morning']['上課時間 Class Sched._day'].value_counts()
weekday_count_A=df1.loc[df1['time_slot']=='afternoon']['上課時間 Class Sched._day'].value_counts()

weekday_count_bins_A=[weekday_count_A[bin] for bin in weekday_bins]
weekday_count_bins_M=[weekday_count_M[bin] for bin in weekday_bins]

# %%
bar = Bar()
bar.add_xaxis(weekday)
bar.add_yaxis(" Morning 課程數目", [7, 5, 13, 12, 7])
bar.add_yaxis(" Afternoon 課程數目",[33, 26, 19, 18, 11] )
bar.set_global_opts(title_opts=opts.TitleOpts(title="通識中心 112-1 課程", subtitle="每週課程 人數分布"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a4ffcfd3fa324f83a954fe7d9e0d7b91" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a4ffcfd3fa324f83a954fe7d9e0d7b91 = echarts.init(
#                     document.getElementById('a4ffcfd3fa324f83a954fe7d9e0d7b91'), 'white', {renderer: 'canvas'});
#                 var option_a4ffcfd3fa324f83a954fe7d9e0d7b91 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": " Morning \u8ab2\u7a0b\u6578\u76ee",
#             "legendHoverLink": true,
#             "data": [
#                 7,
#                 5,
#                 13,
#                 12,
#                 7
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": " Afternoon \u8ab2\u7a0b\u6578\u76ee",
#             "legendHoverLink": true,
#             "data": [
#                 33,
#                 26,
#                 19,
#                 18,
#                 11
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 " Morning \u8ab2\u7a0b\u6578\u76ee",
#                 " Afternoon \u8ab2\u7a0b\u6578\u76ee"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 [
#                     "Mon"
#                 ],
#                 [
#                     "Tue"
#                 ],
#                 [
#                     "Wed"
#                 ],
#                 [
#                     "Thu"
#                 ],
#                 [
#                     "Fri"
#                 ]
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u901a\u8b58\u4e2d\u5fc3 112-1 \u8ab2\u7a0b",
#             "target": "blank",
#             "subtext": "\u6bcf\u9031\u8ab2\u7a0b \u4eba\u6578\u5206\u5e03",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_a4ffcfd3fa324f83a954fe7d9e0d7b91.setOption(option_a4ffcfd3fa324f83a954fe7d9e0d7b91);
#         });
#     </script>

# %% [raw]
# !pip install mitosheet
