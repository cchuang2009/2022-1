# %% [markdown]
# <h1>
# 萬丈高樓平地起
#
# The journey of a thousand miles starts with one step
# </h1>

# %% [markdown]
# Setting up Python Environment
# ---
# 1. Anaconda,
# 2. Google drive + colab plugin: what we will work<b>
#      a.) login your goggle account and choose `drive (雲端硬碟)` service, add `colab` plugin; if no google account,  register one and follow above  to create colab plugin in `drive`.<br>
#      b.) now we can create a new file (colab) to run Python.
# 3. Install `github: copilot` and VS-visual 2022. Although copilot is non-free, it is opened freely for educational use.  In other words, you can follow the instruction on github to register a free copilot license.
#
# **Note**, remember to read the generated codes in detail if you want to use copilot during lecture.
#
# ```Hope everyone has a good start and success in the first step into the data science!```

# %%
from IPython.display import Image

# %%
Image("imgs/copilot-2.png")

# %% [markdown]
# Description
# ---
# A copilot session works on above screenshot, at which we show how to programming Python with copilot:
# 1. `#` means a comment, not code
# 2. At the first definition,
#
# &nbsp;&nbsp;<b><font color="red">def max_</font><font color="black">list(list):</font></b>
#
# (red part is our input, actually), the copilot will guess our intend from the input and suggest the code, according to comment; accept to generate by press `[➔|]` key.
#
# 3. Similar as above, give a comment  in Traditional Chinese: search the maximal prime number in given list:
# the codes in shadow area is the suggestion, and options after the input definition,
#
# ```[accept], [open Github Copilot],...]```
#
# could be selected as you want.

# %% [markdown]
# Homework
# ---
# 1. Setup your working environment for Python programming.
# 2. Does copilot recognize Traditional Chinese?
