# %% [markdown]
# Installation
# ---
# ```
# shell > pip install lux-api
# ```
# Lux would try to create some visualizations which describes the possibly relation between features

# %%
import lux
import pandas as pd

# %%
#file="Laptop_prive.csv"
file="https://raw.githubusercontent.com/Raghavagr/Laptop_Price_Prediction/main/laptop_data.csv"

df = pd.read_csv(file)

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.info()
# Out:
# <class 'lux.core.frame.LuxDataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.intent=['Company','Price']
df
# Out:
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:921: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# /Users/chu-chinghuang/opt/anaconda3/lib/python3.8/site-packages/lux/core/frame.py:632: UserWarning:Traceback (most recent call last):
#   File "/Users/chu-chinghuang/opt/anaconda3/lib/python3.8/site-packages/lux/core/frame.py", line 594, in _ipython_display_
#     self.maintain_recs()
#   File "/Users/chu-chinghuang/opt/anaconda3/lib/python3.8/site-packages/lux/core/frame.py", line 436, in maintain_recs
#     custom_action_collection = custom_actions(rec_df)
#   File "/Users/chu-chinghuang/opt/anaconda3/lib/python3.8/site-packages/lux/action/custom.py", line 76, in custom_actions
#     recommendation = lux.config.actions[action_name].action(ldf)
# ...
