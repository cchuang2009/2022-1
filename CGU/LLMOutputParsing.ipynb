# %%
import openai
openai.api_key="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"

recipe = 'Fish and chips'
query = f"""What is the recipe for {recipe}? 
Return the ingredients list and steps separately."""

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo-0613",
    messages=[{"role": "user", "content": query}])

response_message = response["choices"][0]["message"]
print(response_message['content'])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[1], line 8
#       4 recipe = 'Fish and chips'
#       5 query = f"""What is the recipe for {recipe}?
#       6 Return the ingredients list and steps separately."""
# ----> 8 response = openai.ChatCompletion.create(
#       9     model="gpt-3.5-turbo-0613",
#      10     messages=[{"role": "user", "content": query}])
#      12 response_message = response["choices"][0]["message"]
#      13 print(response_message['content'])
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/openai/api_requestor.py:299, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#    (...)
#     297         request_timeout=request_timeout,
#     298     )
# --> 299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/openai/api_requestor.py:710, in APIRequestor._interpret_response(self, result, stream)
#     702     return (
#     703         self._interpret_response_line(
#     704             line, result.status_code, result.headers, stream=True
#     705         )
#     706         for line in parse_stream(result.iter_lines())
#     707     ), True
#     708 else:
#     709     return (
# --> 710         self._interpret_response_line(
#     711             result.content.decode("utf-8"),
#     712             result.status_code,
#     713             result.headers,
#     714             stream=False,
#     715         ),
#     716         False,
#     717     )
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/openai/api_requestor.py:775, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     773 stream_error = stream and "error" in resp.data
#     774 if stream_error or not 200 <= rcode < 300:
# --> 775     raise self.handle_error_response(
#     776         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777     )
#     778 return resp
#
# RateLimitError: You exceeded your current quota, please check your plan and billing details.

# %%
# !pip install -U openai
# Out:
# Requirement already satisfied: openai in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (0.27.7)
# Collecting openai
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/1e/9f/385c25502f437686e4aa715969e5eaf5c2cb5e5ffa7c5cdd52f3c6ae967a/openai-0.28.1-py3-none-any.whl.metadata
#   Downloading openai-0.28.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.20 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from openai) (4.64.1)
# Requirement already satisfied: aiohttp in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: attrs>=17.3.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 710.9 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.7
#     Uninstalling openai-0.27.7:
#       Successfully uninstalled openai-0.27.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandasai 0.3.0 requires openai<0.28.0,>=0.27.5, but you have openai 0.28.1 which is incompatible.
# pandasai 0.3.0 requires pandas<3.0.0,>=2.0.1, but you have pandas 1.5.3 which is incompatible.
# pandasai 0.3.0 requires python-dotenv<2.0.0,>=1.0.0, but you have python-dotenv 0.20.0 which is incompatible.
# Successfully installed openai-0.28.1

# %%
# !pip install -U langchain
# Out:
# Requirement already satisfied: langchain in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (0.0.220)
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/cb/cc/f1af25eacc650f8bfad7f78f5247c8213473d89e30d34ba106346f7a1e20/langchain-0.0.302-py3-none-any.whl.metadata
#   Downloading langchain-0.0.302-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (2.0.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: anyio<4.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (3.5.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (0.5.14)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<0.1.0,>=0.0.38 (from langchain)
#   Obtaining dependency information for langsmith<0.1.0,>=0.0.38 from https://files.pythonhosted.org/packages/f5/2d/bca3d01bbc128aa9b5c0134ad5f53955aa84a5620b6b07769ba75f7ca96c/langsmith-0.0.40-py3-none-any.whl.metadata
#   Downloading langsmith-0.0.40-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (1.10.9)
# Requirement already satisfied: requests<3,>=2 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from anyio<4.0->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (4.5.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: packaging>=17.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (22.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/chu-chinghuang/opt/anaconda3/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Downloading langchain-0.0.302-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.7 MB/s eta 0:00:0000:0100:010m
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.0.40-py3-none-any.whl (39 kB)
# Installing collected packages: jsonpatch, langsmith, langchain
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.0.220
#     Uninstalling langchain-0.0.220:
#       Successfully uninstalled langchain-0.0.220
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-ai 2.0.1 requires langchain==0.0.220, but you have langchain 0.0.302 which is incompatible.
# jupyter-ai-magics 2.0.1 requires langchain==0.0.220, but you have langchain 0.0.302 which is incompatible.
# Successfully installed jsonpatch-1.33 langchain-0.0.302 langsmith-0.0.40

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.output_parsers import ResponseSchema, StructuredOutputParser
from langchain.llms import GooglePalm, OpenAI


ingredients = ResponseSchema(
        name="ingredients",
        description="The ingredients from recipe, as a unique string.",
    )
steps = ResponseSchema(
        name="steps",
        description="The steps to prepare the recipe, as a unique string.",
    )

output_parser = StructuredOutputParser.from_response_schemas(
    [ingredients, steps]
)

response_format = output_parser.get_format_instructions()
print(response_format)

prompt = ChatPromptTemplate.from_template("What is the recipe for {recipe}? Return the ingredients list and steps separately. \n {format_instructions}")
# Out:
# The output should be a markdown code snippet formatted in the following schema, including the leading and trailing "```json" and "```":
#
# ```json
# {
# 	"ingredients": string  // The ingredients from recipe, as a unique string.
# 	"steps": string  // The steps to prepare the recipe, as a unique string.
# }
# ```

# %%
llm_palm = GooglePalm()

recipe = 'Fish and chips'

formated_prompt = prompt.format(**{"recipe":recipe, "format_instructions":output_parser.get_format_instructions()})

response_palm = llm_palm(formated_prompt)

print("PaLM:")
print(response_palm)
print(output_parser.parse(response_palm))
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llm_palm = GooglePalm()
#       3 recipe = 'Fish and chips'
#       5 formated_prompt = prompt.format(**{"recipe":recipe, "format_instructions":output_parser.get_format_instructions()})
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/langchain/load/serializable.py:74, in Serializable.__init__(self, **kwargs)
#      73 def __init__(self, **kwargs: Any) -> None:
# ---> 74     super().__init__(**kwargs)
#      75     self._lc_kwargs = kwargs
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/pydantic/main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for GooglePalm
# __root__
#   Did not find google_api_key, please add an environment variable `GOOGLE_API_KEY` which contains it, or pass  `google_api_key` as a named parameter. (type=value_error)

# %% [markdown]
# ChatGPT
# ---
# Design a 2-hour talk, about AD 536 in lecture "Energy Resources and Sustainable Civilization"
# Return the Historic Events and the affection after that seperately
#
# And the Output
#
# Title: "AD 536: A Dark Year in History - Lessons for Sustainable Civilization"
#
# **Introduction (15 minutes):**
# - Welcome and introduction to the topic.
# - Briefly explain the relevance of historical events like AD 536 to energy resources and sustainable civilization.
# - Preview the structure of the talk.
#
# **Historic Events (45 minutes):**
# *Discuss the historic events of AD 536, the causes, and the global consequences.*
#
# 1. **The Mysterious Event (15 minutes):**
#    - Explain the unexplained phenomena that occurred in AD 536, such as a mysterious fog and darkened skies.
#    - Mention historical accounts and scientific research on this event.
#
# 2. **Volcanic Eruptions (15 minutes):**
#    - Discuss the major volcanic eruptions, possibly Krakatoa or Ilopango, that caused the climate-altering volcanic winter.
#    - Explain how volcanic ash in the atmosphere led to lower temperatures, crop failures, and famine.
#
# 3. **Impact on Societies (15 minutes):**
#    - Describe how AD 536 affected societies globally, including the fall of empires, migrations, and societal disruptions.
#    - Highlight the importance of agriculture and energy resources during this crisis.
#
# **Break (10 minutes):** Allow the audience to take a short break.
#
# **The Aftermath and Lessons (45 minutes):**
# *Examine the long-term effects of AD 536 and the lessons it holds for sustainable civilization.*
#
# 1. **Recovery and Resilience (15 minutes):**
#    - Discuss how societies adapted, innovated, and eventually recovered from the catastrophe.
#    - Emphasize the role of sustainable resource management and energy solutions in rebuilding.
#
# 2. **Climate Adaptation (15 minutes):**
#    - Explore the concept of climate adaptation and how past events like AD 536 can inform modern strategies.
#    - Discuss the importance of resilient energy systems in the face of climate challenges.
#
# 3. **Sustainable Practices (15 minutes):**
#    - Highlight sustainable practices that emerged in response to environmental challenges, such as improved agriculture and energy efficiency.
#    - Discuss the relevance of these practices in today's sustainable civilization efforts.
#
# **Q&A and Discussion (20 minutes):**
# - Engage the audience with a Q&A session.
# - Encourage discussions about the implications of AD 536 for today's world and sustainable energy resources.
#
# **Conclusion (10 minutes):**
# - Summarize the key takeaways from the talk.
# - Stress the importance of learning from history to build a more resilient and sustainable civilization.
# - Invite attendees to explore further resources on this topic.
#
# **Closing Remarks (5 minutes):**
# - Thank the audience for their participation.
# - Provide additional resources for those interested in learning more.
# - Encourage attendees to apply the lessons from AD 536 to contribute to a more sustainable future.
#
# This two-hour talk will provide a comprehensive exploration of the historic events of AD 536 and their relevance to energy resources and sustainable civilization, offering valuable insights into resilience, adaptation, and responsible resource management in the face of global challenges.
#
#
# **Also compare the Event occurred in Orient and West at the same time, and make a table**
#
#
#
# Certainly, here's a table summarizing the comparison of events that occurred in the Eastern and Western parts of the world around AD 536:
#
# | Aspect                 | Eastern World (Orient)               | Western World (Europe and Mediterranean)         |
# |------------------------|-------------------------------------|--------------------------------------------------|
# | **Climate Impact**     | - Mysterious darkening of skies    | - Dimmed and discolored sun                     |
# |                        | - Cooler temperatures               | - Colder temperatures                           |
# |                        | - Reduced sunlight                  |                                                  |
# | **Societal Disruptions**| - Crop failures and famine           | - Crop failures and food shortages              |
# |                        | - Political upheavals                | - Economic difficulties                         |
# |                        | - Social and political unrest       | - Population decline                            |
# | **Resilience & Recovery**| - Adaptation of agricultural       | - Adaptation of agricultural practices           |
# |                        |   practices                          | - Changes in political structures                |
# |                        | - Recovery from immediate impacts   | - Recovery from immediate impacts               |
# | **Historical Documentation**| Well-documented in Asian     | Well-documented in Byzantine Empire, Europe,    |
# |                        |   historical records                 |   and Mediterranean                              |
# |                        | - Influence on Buddhist tradition  | - Impact on various historical texts             |
# |                        |                                     | - Migration of groups, including barbarians     |
#
# This table provides a concise comparison of the events and their impacts on the Eastern and Western parts of the world around AD 536, highlighting both commonalities and differences in their experiences during this period of environmental challenge.
